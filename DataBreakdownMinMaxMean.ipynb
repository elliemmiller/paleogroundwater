# %% [markdown]
# ## Modern Exfiltration Data Breakdown

# %%
import pandas as pd

# Load the CSV file
file_path = 'modernexfiltrationperm11.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['exfiltration_mm_per_yr']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 2.1133878673255784
# Maximum exfiltration (mm/yr): 5164.1724
# Minimum exfiltration (mm/yr): -191.59122

# %%
import pandas as pd

# Load the CSV file
file_path = 'modernexfiltrationperm12.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['exfiltration_mm_per_yr']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.6683119558306676
# Maximum exfiltration (mm/yr): 1633.0546
# Minimum exfiltration (mm/yr): -60.586464

# %%
import pandas as pd

# Load the CSV file
file_path = 'modernexfiltrationperm13.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['exfiltration_mm_per_yr']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.21133880005018274
# Maximum exfiltration (mm/yr): 516.4172
# Minimum exfiltration (mm/yr): -19.159122

# %%
import pandas as pd

# Load the CSV file
file_path = 'modernexfiltrationperm14.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['exfiltration_mm_per_yr']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.06683119264142405
# Maximum exfiltration (mm/yr): 163.30547
# Minimum exfiltration (mm/yr): -6.058646

# %%
import pandas as pd

# Load the CSV file
file_path = 'modernexfiltrationperm15.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['exfiltration_mm_per_yr']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.02113387856653216
# Maximum exfiltration (mm/yr): 51.64172
# Minimum exfiltration (mm/yr): -1.9159122

# %% [markdown]
# ## Paleo-exfiltration Data Breakdown

# %%
import pandas as pd

# Load the CSV file
file_path = 'paleoexfiltrationperm11mean.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['Exfiltration (mm/yr)']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.30186244595139033
# Maximum exfiltration (mm/yr): 201.97329028485444
# Minimum exfiltration (mm/yr): -1.987550953030642

# %%
import pandas as pd

# Load the CSV file
file_path = 'paleoexfiltrationperm12mean.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['Exfiltration (mm/yr)']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.09545728692758658
# Maximum exfiltration (mm/yr): 63.869562381849846
# Minimum exfiltration (mm/yr): -0.6285187977215173

# %%
import pandas as pd

# Load the CSV file
file_path = 'paleoexfiltrationperm13mean.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['Exfiltration (mm/yr)']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.03018624459513899
# Maximum exfiltration (mm/yr): 20.19732902848544
# Minimum exfiltration (mm/yr): -0.1987550953030642

# %%
import pandas as pd

# Load the CSV file
file_path = 'paleoexfiltrationperm14mean.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['Exfiltration (mm/yr)']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.009545728692758623
# Maximum exfiltration (mm/yr): 6.386956238184983
# Minimum exfiltration (mm/yr): -0.0628518797721517

# %%
import pandas as pd

# Load the CSV file
file_path = 'paleoexfiltrationperm15mean.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['Exfiltration (mm/yr)']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.003018624459513864
# Maximum exfiltration (mm/yr): 2.019732902848544
# Minimum exfiltration (mm/yr): -0.0198755095303064

# %% [markdown]
# # Uncertainty Data Breakdown (Upper)

# %%
import pandas as pd

# Load the CSV file
file_path = 'paleoexfiltrationperm11upperCI.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['Exfiltration (mm/yr)']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.30186508810192686
# Maximum exfiltration (mm/yr): 209.8505365537497
# Minimum exfiltration (mm/yr): -87.89948219326698

# %%
import pandas as pd

# Load the CSV file
file_path = 'paleoexfiltrationperm12upperCI.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['Exfiltration (mm/yr)']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.09545812244894826
# Maximum exfiltration (mm/yr): 66.36056637182706
# Minimum exfiltration (mm/yr): -27.796256888013648

# %%
import pandas as pd

# Load the CSV file
file_path = 'paleoexfiltrationperm13upperCI.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['Exfiltration (mm/yr)']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.030186508810192646
# Maximum exfiltration (mm/yr): 20.98505365537497
# Minimum exfiltration (mm/yr): -8.789948219326698

# %%
import pandas as pd

# Load the CSV file
file_path = 'paleoexfiltrationperm14upperCI.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['Exfiltration (mm/yr)']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.009545812244894793
# Maximum exfiltration (mm/yr): 6.636056637182706
# Minimum exfiltration (mm/yr): -2.7796256888013646

# %%
import pandas as pd

# Load the CSV file
file_path = 'paleoexfiltrationperm15upperCI.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['Exfiltration (mm/yr)']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.0030186508810192284
# Maximum exfiltration (mm/yr): 2.098505365537497
# Minimum exfiltration (mm/yr): -0.8789948219326698

# %% [markdown]
# # Uncertainty Data Breakdown (Lower)

# %%
import pandas as pd

# Load the CSV file
file_path = 'paleoexfiltrationperm11lowerCI.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['Exfiltration (mm/yr)']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.301844718780237
# Maximum exfiltration (mm/yr): 191.5881192362176
# Minimum exfiltration (mm/yr): -37.44997852650646

# %%
import pandas as pd

# Load the CSV file
file_path = 'paleoexfiltrationperm12lowerCI.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['Exfiltration (mm/yr)']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.09545168110385496
# Maximum exfiltration (mm/yr): 60.58548294143667
# Minimum exfiltration (mm/yr): -11.842723046815694

# %%
import pandas as pd

# Load the CSV file
file_path = 'paleoexfiltrationperm13lowerCI.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['Exfiltration (mm/yr)']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.03018447187802365
# Maximum exfiltration (mm/yr): 19.15881192362176
# Minimum exfiltration (mm/yr): -3.744997852650646

# %%
import pandas as pd

# Load the CSV file
file_path = 'paleoexfiltrationperm14lowerCI.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['Exfiltration (mm/yr)']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.009545168110385464
# Maximum exfiltration (mm/yr): 6.058548294143668
# Minimum exfiltration (mm/yr): -1.184272304681569

# %%
import pandas as pd

# Load the CSV file
file_path = 'paleoexfiltrationperm15lowerCI.csv'  # your CSV file
df = pd.read_csv(file_path)

# Extract the exfiltration column
exfil_col = df['Exfiltration (mm/yr)']

# Calculate mean, max, min
mean_exfil = exfil_col.mean()
max_exfil = exfil_col.max()
min_exfil = exfil_col.min()

# Print results
print(f"Mean exfiltration (mm/yr): {mean_exfil}")
print(f"Maximum exfiltration (mm/yr): {max_exfil}")
print(f"Minimum exfiltration (mm/yr): {min_exfil}")
# Out:
# Mean exfiltration (mm/yr): 0.0030184471878023297
# Maximum exfiltration (mm/yr): 1.915881192362176
# Minimum exfiltration (mm/yr): -0.3744997852650646

# %% [markdown]
# # Put everything together

# %%
import pandas as pd

df = pd.DataFrame({
    "Permeability (m²)": [1e-11, 1e-12, 1e-13, 1e-14, 1e-15],

    "Modern Mean (mm yr⁻¹)": [2.113, 0.668, 0.211, 0.067, 0.021],
    "Modern Min (mm yr⁻¹)": [-191.59, -60.59, -19.16, -6.06, -1.92],
    "Modern Max (mm yr⁻¹)": [5164.17, 1633.05, 516.42, 163.31, 51.64],

    "Paleo Mean (mm yr⁻¹)": [0.302, 0.095, 0.030, 0.0095, 0.0030],
    "Paleo Min (mm yr⁻¹)": [-1.99, -0.63, -0.20, -0.06, -0.020],
    "Paleo Max (mm yr⁻¹)": [201.97, 63.87, 20.20, 6.39, 2.02],

    "Paleo Upper CI Min (mm yr⁻¹)": [-87.90, -27.80, -8.79, -2.78, -0.88],
    "Paleo Upper CI Max (mm yr⁻¹)": [209.85, 66.36, 20.99, 6.64, 2.10],

    "Paleo Lower CI Min (mm yr⁻¹)": [-37.45, -11.84, -3.74, -1.18, -0.37],
    "Paleo Lower CI Max (mm yr⁻¹)": [191.59, 60.59, 19.16, 6.06, 1.92],
})

# Format permeability nicely
df["Permeability (m²)"] = df["Permeability (m²)"].map(lambda x: f"{x:.0e}")

df
# Out:
#   Permeability (m²)  Modern Mean (mm yr⁻¹)  Modern Min (mm yr⁻¹)  \
# 0             1e-11                  2.113               -191.59
# 1             1e-12                  0.668                -60.59
# 2             1e-13                  0.211                -19.16
# 3             1e-14                  0.067                 -6.06
# 4             1e-15                  0.021                 -1.92
#
#    Modern Max (mm yr⁻¹)  Paleo Mean (mm yr⁻¹)  Paleo Min (mm yr⁻¹)  \
# 0               5164.17                0.3020                -1.99
# 1               1633.05                0.0950                -0.63
# 2                516.42                0.0300                -0.20
# 3                163.31                0.0095                -0.06
# 4                 51.64                0.0030                -0.02
#
#    Paleo Max (mm yr⁻¹)  Paleo Upper CI Min (mm yr⁻¹)  \
# 0               201.97                        -87.90
# 1                63.87                        -27.80
# 2                20.20                         -8.79
# 3                 6.39                         -2.78
# 4                 2.02                         -0.88
#
#    Paleo Upper CI Max (mm yr⁻¹)  Paleo Lower CI Min (mm yr⁻¹)  \
# 0                        209.85                        -37.45
# 1                         66.36                        -11.84
# 2                         20.99                         -3.74
# 3                          6.64                         -1.18
# 4                          2.10                         -0.37
#
#    Paleo Lower CI Max (mm yr⁻¹)
# 0                        191.59
# 1                         60.59
# 2                         19.16
# 3                          6.06
# 4                          1.92
